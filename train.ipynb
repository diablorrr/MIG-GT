# %%
# %matplotlib inline

# %%
# !python main.py --gpu 0 --seed 1 --dataset baby --result_dir results --method mig_gt
# Out:
# generate argument --lr with type <class 'float'>
# generate argument --lr_decay with type <class 'float'>
# generate argument --lr_decay_min with type <class 'float'>
# generate argument --l2_coef with type <class 'float'>
# generate argument --batch_size with type <class 'int'>
# generate argument --num_epochs with type <class 'int'>
# generate argument --num_negs with type <class 'int'>
# generate argument --patience with type <class 'int'>
# generate argument --validation_freq with type <class 'int'>
# generate argument --embedding_size with type <class 'int'>
# generate argument --feat_hidden_units with type <class 'int'>
# generate argument --k_e with type <class 'int'>
# generate argument --k_t with type <class 'int'>
# generate argument --k_v with type <class 'int'>
# generate argument --alpha with type <class 'float'>
# generate argument --beta with type <class 'float'>
# generate argument --input_feat_drop_rate with type <class 'float'>
# ...

# %%
from IPython.display import Image

# %%
Image(filename="train_val_loss.png")

# %%
Image(filename="valid_metrics.png")
